# %%
import requests as r
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
options = webdriver.ChromeOptions()
options.add_argument('--headless')
import time
from bs4 import BeautifulSoup as bs
driver = webdriver.Chrome(options=options)
driver.get("https://images.google.com/")
searchbox = driver.find_element(By.TAG_NAME,"textarea")
search_keys = driver.find_elements(By.TAG_NAME,"button")
print(len(search_keys))
searchbox.send_keys("windows")
search_key = search_keys[1]
search_key.click()
page = bs(driver.page_source,"lxml")
images =page.select("img")
for x in images:
    try:
        print(x["src"])
    except:
        pass
# Out:
# 2
# https://fonts.gstatic.com/s/i/productlogos/lens_camera/v1/192px.svg
# https://www.gstatic.com/ui/v1/menu/light_thumbnail2.png
# https://www.gstatic.com/ui/v1/menu/dark_thumbnail2.png
# https://www.gstatic.com/ui/v1/menu/device_default_thumbnail2.png
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZ8c9rURHlweJQMmERUpJFJ6UzTQTSNmlq5Wq9XuuXdOVzctuRHLC91Ck&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTeNoMGdzhtMCIOkh5Xp88ZPv_mkwy7IElh_ALlDiCu3q5RI8eFOyYt4yw&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTm20jBFcPR9PGdl_EJMBNdF91G5kywvb-nV-QxdwKe69HzEjwEoF5-PQA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrUAI_S2e1WRp7Y_3-NkZjPFJPikj4URxBX-bH7TQSfnLFZsFtJkMYU2Y&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsjOcH5U8LRCBv6CYCiQwXwtpO1UYXtSK0lNqOP2FMcoDHhmWUNm3d0C8&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbtQfwIoMTNqCmZg0L9qsuah1tnxWgDWkNcCNOvyqce3a1fjXH0ujGTM0&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRO_S8UQETGAUdiodv0xlc-_cSxoUcE1smZqjGRrhFRSoUMxouWhNY7XiE&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTWG-zH_j1yeqhYdyTHCbO3vwN8xsictrUSTPzeYeeRdZ40UDu3O5zwdN0&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8XRGY0Ioj3fn1xRP2sgG5-ZkChphTXSDZM_6DMaiJckLOgNr3kUAPMsI&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTyZPOAfEA-ViObzsevNlXl1VpkIviofIiIOLzyybJhqs0SjHz3ndGg6Ao&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSrC5CDPXtEwYi2jAI4DM-fSwpltujuNRHu3ggO-q49T-UkT-Bs9wDF7aI&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSBRJSYn4WIbHLEMmJmTT_NGZKtnmFIsLjU9pikXz1P-824JNL_GpwU85A&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS4GVgm2WJKIfFd2BVEBeIv4MWCPSL7qsmJkkpfvU9yTBUm-ZIN8p2fr4Y&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRziqExvZ7d0qCY3Lo8UZN_8m7nqTgXeTUbEymeXp1Q8wCqOc6WkHneGko&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQGzv5UYL1WDtl018WLLiYcQ0q4qL-2z0DF37evvC9sDmY9IXFJe2hJ9Yo&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgy36AFlJe_hpZDvQWnK3v0J3evfK47eGPXJ9hZ5pDUJgZfsqObEJynCU&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSu3t7vAO8eyJeeJSoDWFS3woRV_PsTSQ4zXPKb78jUCIYAM-wf_0tcXSw&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSfv6grs-UyUtkG-ESTyPlc51x_e8vLJsvBD_ZT_i3HCZ9nZnV8ABHm24&usqp=CAU
# data:image/png;base64,...
# ...:image/png;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/png;base64,...
# ...:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
